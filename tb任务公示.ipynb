# %%
import pandas as pd

# %%
df.columns
# Out:
# Index(['标题', '是否是子任务', '父任务', '父任务 ObjectId', '任务类型', '执行者', '更新时间', '开始时间',
#        '截止时间', '备注', '优先级', '标签', '关联任务', '关联文件', '关联日程', '关联分享', '创建者',
#        '创建时间', '是否完成', '完成时间', '分组', '列表', '逾期天数', '已逾期'],
#       dtype='object')

# %%
df = pd.read_table('https://raw.githubusercontent.com/bog5d/Feng-chao/master/tb%E5%88%86%E6%9E%90%E6%BA%90%E6%95%B0%E6%8D%AE').fillna('/')


df = df[['标题',  '执行者', '更新时间','截止时间', '备注', '优先级', '标签', '关联任务', '关联文件', '关联日程', '关联分享', '创建者',
          '创建时间', '是否完成', '完成时间',  '逾期天数', '已逾期']]
df.head()
# Out:
#                 标题                                                执行者  \
# 0        完善灶具top系列  代华强(accounts_5c7366f2b6f1560018457c7e@mail.tea...
# 1  出货打款测算一轮，并公布给梦锟                               王波(331046596@qq.com)
# 2           初步测算一轮                               王波(331046596@qq.com)
# 3  确定大观客户3号上来的具体时间  李锟(accounts_59d8384f3237cf0e8dc0d4be@mail.team...
# 4      收集綦江红星美凯龙照片  李锟(accounts_59d8384f3237cf0e8dc0d4be@mail.team...
#
#                   更新时间                 截止时间 备注 优先级 标签  关联任务  关联文件  关联日程  关联分享  \
# 0  2019-12-02 11:18:41  2019-12-03 18:00:00  /  普通  /     0     0     0     0
# 1  2019-12-02 11:50:47  2019-12-02 18:00:00  /  普通  /     0     0     0     0
# 2  2019-12-02 11:50:45                    /  /  普通  /     0     0     0     0
# 3  2019-12-02 10:14:03  2019-12-02 18:00:00  /  普通  /     0     0     0     0
# 4  2019-12-02 10:13:59  2019-12-02 18:00:00  /  普通  /     0     0     0     0
#
# ...

# %%
df = df[['标题', '执行者', '更新时间', '截止时间', '备注', 
      '创建者', '创建时间', '是否完成', '完成时间', '逾期天数', '已逾期']]
df1 = df.copy()[['标题', '执行者', '是否完成', '完成时间']]
df1
# Out:
#                              标题  \
# 0                     完善灶具top系列
# 1               出货打款测算一轮，并公布给梦锟
# 2                        初步测算一轮
# 3               确定大观客户3号上来的具体时间
# 4                   收集綦江红星美凯龙照片
# 5                   收集潼南灯具城二店照片
# 6                   查看健壕的tb有啥问题
# 7                     灶具竞品整理15个
# 8                          梳理烟机
# 9                   3.扫街，7家有效客户
# 10                 2.再次拜访电热意向客户
# 11                  1.整理上月的报销单据
# 12                 check 任务建立情况
# 13                    提交打款提货数据。
# 14               购买明天开会需要的水果和小吃
# 15  拉一台电热机械式和零冷水到分部，售后培训，需要波哥协助
# 16            从万景腾喊货拉拉备货厨电到大坪售后
# 17      区县导购12月3号开会住宿了12月2晚住宿预订
# 18                          交照片
# 19                见张中伟（价格体系怎么给）
# 20                         手表发瑞
# 21                   公布共读社的时间安排
# 22                      更新竞品灶十个
# 23                  问周总推荐主城批发客户
# 24             新品上样的名单交上去。check
# 25                     给曾林周发出腰线
# 26                     拜访綦江火王客户
# 27                     拜访綦江美的客户
# ...
